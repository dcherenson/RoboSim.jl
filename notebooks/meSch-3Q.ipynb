# %%
import Pkg; Pkg.activate("../"); Pkg.instantiate()
# Out:
#   Activating project at `~/Kaleb_Data/PhD_Research/mEclares`
# Precompiling project...
#   ? Convex

# %%
using LinearAlgebra
using BlockDiagonals
using ForwardDiff
using ControlSystems
using ComponentArrays
using Parameters: @unpack
using StaticArrays
using Plots

# %%
# include dependencies
include("../src/utils.jl")
include("../src/ExpDynamicsLibrary.jl")
include("../src/RefTrajectoryLibrary.jl")
include("../src/ExpControllerLibrary.jl")
include("../src/Visualization.jl")
include("../src/RefTrajectoryLibrary.jl")
# Out:
# Precompiling Convex
#         Info Given Convex was explicitly requested, output will be shown live
# WARNING: Method definition hcat(Union{Number, AbstractArray{T, N} where N where T}...) in module Base at abstractarray.jl:2003 overwritten in module Convex at /home/kbn/.julia/packages/Convex/uI27T/src/atoms/affine/stack.jl:117.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
#   ? Convex
# [ Info: Precompiling Convex [f65535da-76fb-5f13-bab9-19810c17039a]
# WARNING: Method definition hcat(Union{Number, AbstractArray{T, N} where N where T}...) in module Base at abstractarray.jl:2003 overwritten in module Convex at /home/kbn/.julia/packages/Convex/uI27T/src/atoms/affine/stack.jl:117.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# [ Info: Skipping precompilation since __precompile__(false). Importing Convex [f65535da-76fb-5f13-bab9-19810c17039a].
# WARNING: replacing module RefTrajLib.
# Main.RefTrajLib

# %%
include("../src/ExpmeSchFlylab_3.jl")
# Out:
# Main.meSchExpDIFL

# %%
## Testing meSch

# Initial state
soc_init = 90.0
N = 1.0
int_pos_1 = [-2.0; 0.0; 0.0]
int_pos_2 = [1.0; 0.0; 0.0]
int_pos_3 = [-0.5; -3.2; 0.0]


# Get the quad_parameters
quad_p = ExpDyn.quadrotor_parameters

## Define the quad's initial condition
quad1_ic = ComponentArray(
    x = int_pos_1,
    v = zeros(3),
    R = 1.0(I(3)) |> collect, 
    Ω = zeros(3),
    ω = 2*ExpDyn.hover_ω(quad_p),
    soc = soc_init
);

quad2_ic = ComponentArray(
    x = int_pos_2,
    v = zeros(3),
    R = 1.0(I(3)) |> collect, 
    Ω = zeros(3),
    ω = 2*ExpDyn.hover_ω(quad_p),
    soc = soc_init
);

quad3_ic = ComponentArray(
    x = int_pos_3,
    v = zeros(3),
    R = 1.0(I(3)) |> collect, 
    Ω = zeros(3),
    ω = 2*ExpDyn.hover_ω(quad_p),
    soc = soc_init
);

discharge_rate = 0.6667
T_SIM = 300.0

quad_ic = ComponentArray(
    quad1 = quad1_ic,
    quad2 = quad2_ic,
    quad3 = quad3_ic,
)

# params = meSchExpDI.simulate(quad_states, 0., T_SIM, discharge_rate)
sol_nc, params = meSchExpDIFL.simulate(quad_ic, 0., T_SIM, discharge_rate)
X1 = sol_nc.u;
# T = sol_nc.t;
# println("size of state vecs: $(size(sol_nc.u))")
# println("size of state vecs: $(size(sol_nc.t))")
# Out:
# =========== In recompute_committed ==============
# Current time: 0.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 90.0
# current_soc: 90.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 90.0
# current_soc: 90.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 90.0
# current_soc: 90.0
# Remaining flight time 1st quad: 134.99325033748315
# Remaining flight time: 134.99325033748315
# TC: 12.900000000000002
# TF - TC > k(T_c + T_delta): 122.09325033748314 > 51.0
# Expected gap: 71.09325033748314
# Gap satisfied: true
# Remaining flight time: 134.99325033748315
# TC: 12.900000000000002
# TF - TC > k(T_c + T_delta): 122.09325033748314 > 26.0
# Expected gap: 96.09325033748314
# Gap satisfied: true
# current time: 0.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 1.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 88.99995000000088
# current_soc: 88.99995000000088
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 88.99995000000088
# current_soc: 88.99995000000088
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 88.99995000000088
# current_soc: 88.99995000000088
# Remaining flight time 1st quad: 133.49325033748445
# Remaining flight time: 133.49325033748445
# TC: 12.900000000000002
# TF - TC > k(T_c + T_delta): 120.59325033748445 > 51.0
# Expected gap: 69.59325033748445
# Gap satisfied: true
# Remaining flight time: 133.49325033748445
# TC: 12.900000000000002
# TF - TC > k(T_c + T_delta): 120.59325033748445 > 26.0
# Expected gap: 94.59325033748445
# Gap satisfied: true
# current time: 1.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 3.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 87.99990000000192
# current_soc: 87.99990000000192
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 87.99990000000192
# current_soc: 87.99990000000192
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 87.99990000000192
# current_soc: 87.99990000000192
# Remaining flight time 1st quad: 131.99325033748602
# Remaining flight time: 131.99325033748602
# TC: 12.900000000000002
# TF - TC > k(T_c + T_delta): 119.09325033748601 > 51.0
# Expected gap: 68.09325033748601
# Gap satisfied: true
# Remaining flight time: 131.99325033748602
# TC: 12.900000000000002
# TF - TC > k(T_c + T_delta): 119.09325033748601 > 26.0
# Expected gap: 93.09325033748601
# Gap satisfied: true
# current time: 3.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 4.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 86.99985000000278
# current_soc: 86.99985000000278
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 86.99985000000278
# current_soc: 86.99985000000278
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 86.99985000000278
# current_soc: 86.99985000000278
# Remaining flight time 1st quad: 130.4932503374873
# Remaining flight time: 130.4932503374873
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 117.59325033748729 > 51.0
# Expected gap: 66.59325033748729
# Gap satisfied: true
# Remaining flight time: 130.4932503374873
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 117.59325033748729 > 26.0
# Expected gap: 91.59325033748729
# Gap satisfied: true
# current time: 4.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 6.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 85.9998000000033
# current_soc: 85.9998000000033
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 85.9998000000033
# current_soc: 85.9998000000033
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 85.9998000000033
# current_soc: 85.9998000000033
# Remaining flight time 1st quad: 128.9932503374881
# Remaining flight time: 128.9932503374881
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 116.09325033748809 > 51.0
# Expected gap: 65.09325033748809
# Gap satisfied: true
# Remaining flight time: 128.9932503374881
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 116.09325033748809 > 26.0
# Expected gap: 90.09325033748809
# Gap satisfied: true
# current time: 6.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 7.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 84.99975000000383
# current_soc: 84.99975000000383
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 84.99975000000383
# current_soc: 84.99975000000383
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 84.99975000000383
# current_soc: 84.99975000000383
# Remaining flight time 1st quad: 127.49325033748887
# Remaining flight time: 127.49325033748887
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 114.59325033748888 > 51.0
# Expected gap: 63.59325033748888
# Gap satisfied: true
# Remaining flight time: 127.49325033748887
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 114.59325033748888 > 26.0
# Expected gap: 88.59325033748888
# Gap satisfied: true
# current time: 7.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 9.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 83.99970000000452
# current_soc: 83.99970000000452
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 83.99970000000452
# current_soc: 83.99970000000452
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 83.99970000000452
# current_soc: 83.99970000000452
# Remaining flight time 1st quad: 125.99325033748991
# Remaining flight time: 125.99325033748991
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 113.0932503374899 > 51.0
# Expected gap: 62.093250337489906
# Gap satisfied: true
# Remaining flight time: 125.99325033748991
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 113.0932503374899 > 26.0
# Expected gap: 87.0932503374899
# Gap satisfied: true
# current time: 9.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 10.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 82.9996500000053
# current_soc: 82.9996500000053
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 82.9996500000053
# current_soc: 82.9996500000053
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 82.9996500000053
# current_soc: 82.9996500000053
# Remaining flight time 1st quad: 124.49325033749109
# Remaining flight time: 124.49325033749109
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 111.5932503374911 > 51.0
# Expected gap: 60.5932503374911
# Gap satisfied: true
# Remaining flight time: 124.49325033749109
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 111.5932503374911 > 26.0
# Expected gap: 85.5932503374911
# Gap satisfied: true
# current time: 10.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 12.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 81.99960000000608
# current_soc: 81.99960000000608
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 81.99960000000608
# current_soc: 81.99960000000608
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 81.99960000000608
# current_soc: 81.99960000000608
# Remaining flight time 1st quad: 122.99325033749226
# Remaining flight time: 122.99325033749226
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 110.09325033749226 > 51.0
# Expected gap: 59.093250337492265
# Gap satisfied: true
# Remaining flight time: 122.99325033749226
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 110.09325033749226 > 26.0
# Expected gap: 84.09325033749226
# Gap satisfied: true
# current time: 12.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 13.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 80.99955000000686
# current_soc: 80.99955000000686
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 80.99955000000686
# current_soc: 80.99955000000686
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 80.99955000000686
# current_soc: 80.99955000000686
# Remaining flight time 1st quad: 121.49325033749342
# Remaining flight time: 121.49325033749342
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 108.59325033749343 > 51.0
# Expected gap: 57.59325033749343
# Gap satisfied: true
# Remaining flight time: 121.49325033749342
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 108.59325033749343 > 26.0
# Expected gap: 82.59325033749343
# Gap satisfied: true
# current time: 13.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 15.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 79.99950000000764
# current_soc: 79.99950000000764
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 79.99950000000764
# current_soc: 79.99950000000764
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 79.99950000000764
# current_soc: 79.99950000000764
# Remaining flight time 1st quad: 119.9932503374946
# Remaining flight time: 119.9932503374946
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 107.0932503374946 > 51.0
# Expected gap: 56.093250337494595
# Gap satisfied: true
# Remaining flight time: 119.9932503374946
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 107.0932503374946 > 26.0
# Expected gap: 81.0932503374946
# Gap satisfied: true
# current time: 15.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 16.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 78.99945000000811
# current_soc: 78.99945000000811
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 78.99945000000811
# current_soc: 78.99945000000811
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 78.99945000000811
# current_soc: 78.99945000000811
# Remaining flight time 1st quad: 118.4932503374953
# Remaining flight time: 118.4932503374953
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 105.5932503374953 > 51.0
# Expected gap: 54.593250337495306
# Gap satisfied: true
# Remaining flight time: 118.4932503374953
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 105.5932503374953 > 26.0
# Expected gap: 79.5932503374953
# Gap satisfied: true
# current time: 16.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 18.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 77.99940000000795
# current_soc: 77.99940000000795
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 77.99940000000795
# current_soc: 77.99940000000795
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 77.99940000000795
# current_soc: 77.99940000000795
# Remaining flight time 1st quad: 116.99325033749506
# Remaining flight time: 116.99325033749506
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 104.09325033749505 > 51.0
# Expected gap: 53.09325033749505
# Gap satisfied: true
# Remaining flight time: 116.99325033749506
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 104.09325033749505 > 26.0
# Expected gap: 78.09325033749505
# Gap satisfied: true
# current time: 18.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 19.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 76.9993500000078
# current_soc: 76.9993500000078
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 76.9993500000078
# current_soc: 76.9993500000078
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 76.9993500000078
# current_soc: 76.9993500000078
# Remaining flight time 1st quad: 115.49325033749483
# Remaining flight time: 115.49325033749483
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 102.59325033749482 > 51.0
# Expected gap: 51.59325033749482
# Gap satisfied: true
# Remaining flight time: 115.49325033749483
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 102.59325033749482 > 26.0
# Expected gap: 76.59325033749482
# Gap satisfied: true
# current time: 19.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 21.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 75.99930000000764
# current_soc: 75.99930000000764
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 75.99930000000764
# current_soc: 75.99930000000764
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 75.99930000000764
# current_soc: 75.99930000000764
# Remaining flight time 1st quad: 113.99325033749459
# Remaining flight time: 113.99325033749459
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 101.0932503374946 > 51.0
# Expected gap: 50.093250337494595
# Gap satisfied: true
# Remaining flight time: 113.99325033749459
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 101.0932503374946 > 26.0
# Expected gap: 75.0932503374946
# Gap satisfied: true
# current time: 21.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 22.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 74.99925000000748
# current_soc: 74.99925000000748
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 74.99925000000748
# current_soc: 74.99925000000748
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 74.99925000000748
# current_soc: 74.99925000000748
# Remaining flight time 1st quad: 112.49325033749435
# Remaining flight time: 112.49325033749435
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 99.59325033749434 > 51.0
# Expected gap: 48.59325033749434
# Gap satisfied: true
# Remaining flight time: 112.49325033749435
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 99.59325033749434 > 26.0
# Expected gap: 73.59325033749434
# Gap satisfied: true
# current time: 22.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 24.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 73.99920000000732
# current_soc: 73.99920000000732
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 73.99920000000732
# current_soc: 73.99920000000732
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 73.99920000000732
# current_soc: 73.99920000000732
# Remaining flight time 1st quad: 110.99325033749412
# Remaining flight time: 110.99325033749412
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 98.09325033749411 > 51.0
# Expected gap: 47.09325033749411
# Gap satisfied: true
# Remaining flight time: 110.99325033749412
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 98.09325033749411 > 26.0
# Expected gap: 72.09325033749411
# Gap satisfied: true
# current time: 24.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 25.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 72.99915000000716
# current_soc: 72.99915000000716
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 72.99915000000716
# current_soc: 72.99915000000716
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 72.99915000000716
# current_soc: 72.99915000000716
# Remaining flight time 1st quad: 109.49325033749388
# Remaining flight time: 109.49325033749388
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 96.59325033749388 > 51.0
# Expected gap: 45.593250337493885
# Gap satisfied: true
# Remaining flight time: 109.49325033749388
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 96.59325033749388 > 26.0
# Expected gap: 70.59325033749388
# Gap satisfied: true
# current time: 25.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 27.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 71.999100000007
# current_soc: 71.999100000007
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 71.999100000007
# current_soc: 71.999100000007
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 71.999100000007
# current_soc: 71.999100000007
# Remaining flight time 1st quad: 107.99325033749363
# Remaining flight time: 107.99325033749363
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 95.09325033749363 > 51.0
# Expected gap: 44.09325033749363
# Gap satisfied: true
# Remaining flight time: 107.99325033749363
# TC: 12.899999999999999
# TF - TC > k(T_c + T_delta): 95.09325033749363 > 26.0
# Expected gap: 69.09325033749363
# Gap satisfied: true
# current time: 27.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 28.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 70.99905000000685
# current_soc: 70.99905000000685
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 70.99905000000685
# current_soc: 70.99905000000685
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 70.99905000000685
# current_soc: 70.99905000000685
# Remaining flight time 1st quad: 106.49325033749341
# Remaining flight time: 106.49325033749341
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 93.5932503374934 > 51.0
# Expected gap: 42.5932503374934
# Gap satisfied: true
# Remaining flight time: 106.49325033749341
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 93.5932503374934 > 26.0
# Expected gap: 67.5932503374934
# Gap satisfied: true
# current time: 28.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 30.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 69.99900000000669
# current_soc: 69.99900000000669
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 69.99900000000669
# current_soc: 69.99900000000669
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 69.99900000000669
# current_soc: 69.99900000000669
# Remaining flight time 1st quad: 104.99325033749317
# Remaining flight time: 104.99325033749317
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 92.09325033749316 > 51.0
# Expected gap: 41.09325033749316
# Gap satisfied: true
# Remaining flight time: 104.99325033749317
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 92.09325033749316 > 26.0
# Expected gap: 66.09325033749316
# Gap satisfied: true
# current time: 30.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 31.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 68.99895000000653
# current_soc: 68.99895000000653
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 68.99895000000653
# current_soc: 68.99895000000653
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 68.99895000000653
# current_soc: 68.99895000000653
# Remaining flight time 1st quad: 103.49325033749292
# Remaining flight time: 103.49325033749292
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 90.59325033749292 > 51.0
# Expected gap: 39.59325033749292
# Gap satisfied: true
# Remaining flight time: 103.49325033749292
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 90.59325033749292 > 26.0
# Expected gap: 64.59325033749292
# Gap satisfied: true
# current time: 31.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 33.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 67.99890000000677
# current_soc: 67.99890000000677
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 67.99890000000677
# current_soc: 67.99890000000677
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 67.99890000000677
# current_soc: 67.99890000000677
# Remaining flight time 1st quad: 101.9932503374933
# Remaining flight time: 101.9932503374933
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 89.09325033749329 > 51.0
# Expected gap: 38.09325033749329
# Gap satisfied: true
# Remaining flight time: 101.9932503374933
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 89.09325033749329 > 26.0
# Expected gap: 63.09325033749329
# Gap satisfied: true
# current time: 33.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 34.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 66.99885000000721
# current_soc: 66.99885000000721
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 66.99885000000721
# current_soc: 66.99885000000721
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 66.99885000000721
# current_soc: 66.99885000000721
# Remaining flight time 1st quad: 100.49325033749395
# Remaining flight time: 100.49325033749395
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 87.59325033749394 > 51.0
# Expected gap: 36.59325033749394
# Gap satisfied: true
# Remaining flight time: 100.49325033749395
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 87.59325033749394 > 26.0
# Expected gap: 61.59325033749394
# Gap satisfied: true
# current time: 34.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 36.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 65.99880000000765
# current_soc: 65.99880000000765
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 65.99880000000765
# current_soc: 65.99880000000765
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 65.99880000000765
# current_soc: 65.99880000000765
# Remaining flight time 1st quad: 98.9932503374946
# Remaining flight time: 98.9932503374946
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 86.0932503374946 > 51.0
# Expected gap: 35.093250337494595
# Gap satisfied: true
# Remaining flight time: 98.9932503374946
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 86.0932503374946 > 26.0
# Expected gap: 60.093250337494595
# Gap satisfied: true
# current time: 36.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 37.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 64.99875000000809
# current_soc: 64.99875000000809
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 64.99875000000809
# current_soc: 64.99875000000809
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 64.99875000000809
# current_soc: 64.99875000000809
# Remaining flight time 1st quad: 97.49325033749527
# Remaining flight time: 97.49325033749527
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 84.59325033749526 > 51.0
# Expected gap: 33.59325033749526
# Gap satisfied: true
# Remaining flight time: 97.49325033749527
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 84.59325033749526 > 26.0
# Expected gap: 58.59325033749526
# Gap satisfied: true
# current time: 37.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 39.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 63.99870000000852
# current_soc: 63.99870000000852
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 63.99870000000852
# current_soc: 63.99870000000852
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 63.99870000000852
# current_soc: 63.99870000000852
# Remaining flight time 1st quad: 95.99325033749591
# Remaining flight time: 95.99325033749591
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 83.0932503374959 > 51.0
# Expected gap: 32.0932503374959
# Gap satisfied: true
# Remaining flight time: 95.99325033749591
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 83.0932503374959 > 26.0
# Expected gap: 57.0932503374959
# Gap satisfied: true
# current time: 39.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 40.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 62.99865000000849
# current_soc: 62.99865000000849
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 62.99865000000849
# current_soc: 62.99865000000849
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 62.99865000000849
# current_soc: 62.99865000000849
# Remaining flight time 1st quad: 94.49325033749587
# Remaining flight time: 94.49325033749587
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 81.59325033749586 > 51.0
# Expected gap: 30.59325033749586
# Gap satisfied: true
# Remaining flight time: 94.49325033749587
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 81.59325033749586 > 26.0
# Expected gap: 55.59325033749586
# Gap satisfied: true
# current time: 40.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 42.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 61.99860000000846
# current_soc: 61.99860000000846
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 61.99860000000846
# current_soc: 61.99860000000846
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 61.99860000000846
# current_soc: 61.99860000000846
# Remaining flight time 1st quad: 92.99325033749582
# Remaining flight time: 92.99325033749582
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 80.09325033749582 > 51.0
# Expected gap: 29.093250337495817
# Gap satisfied: true
# Remaining flight time: 92.99325033749582
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 80.09325033749582 > 26.0
# Expected gap: 54.09325033749582
# Gap satisfied: true
# current time: 42.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 43.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 60.99855000000843
# current_soc: 60.99855000000843
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 60.99855000000843
# current_soc: 60.99855000000843
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 60.99855000000843
# current_soc: 60.99855000000843
# Remaining flight time 1st quad: 91.49325033749578
# Remaining flight time: 91.49325033749578
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 78.59325033749577 > 51.0
# Expected gap: 27.593250337495775
# Gap satisfied: true
# Remaining flight time: 91.49325033749578
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 78.59325033749577 > 26.0
# Expected gap: 52.593250337495775
# Gap satisfied: true
# current time: 43.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 45.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 59.9985000000084
# current_soc: 59.9985000000084
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 59.9985000000084
# current_soc: 59.9985000000084
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 59.9985000000084
# current_soc: 59.9985000000084
# Remaining flight time 1st quad: 89.99325033749572
# Remaining flight time: 89.99325033749572
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 77.09325033749572 > 51.0
# Expected gap: 26.093250337495718
# Gap satisfied: true
# Remaining flight time: 89.99325033749572
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 77.09325033749572 > 26.0
# Expected gap: 51.09325033749572
# Gap satisfied: true
# current time: 45.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 46.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 58.99845000000837
# current_soc: 58.99845000000837
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 58.99845000000837
# current_soc: 58.99845000000837
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 58.99845000000837
# current_soc: 58.99845000000837
# Remaining flight time 1st quad: 88.49325033749568
# Remaining flight time: 88.49325033749568
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 75.59325033749568 > 51.0
# Expected gap: 24.593250337495675
# Gap satisfied: true
# Remaining flight time: 88.49325033749568
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 75.59325033749568 > 26.0
# Expected gap: 49.593250337495675
# Gap satisfied: true
# current time: 46.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 48.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 57.99840000000834
# current_soc: 57.99840000000834
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 57.99840000000834
# current_soc: 57.99840000000834
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 57.99840000000834
# current_soc: 57.99840000000834
# Remaining flight time 1st quad: 86.99325033749564
# Remaining flight time: 86.99325033749564
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 74.09325033749563 > 51.0
# Expected gap: 23.093250337495633
# Gap satisfied: true
# Remaining flight time: 86.99325033749564
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 74.09325033749563 > 26.0
# Expected gap: 48.09325033749563
# Gap satisfied: true
# current time: 48.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 49.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 56.99835000000831
# current_soc: 56.99835000000831
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 56.99835000000831
# current_soc: 56.99835000000831
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 56.99835000000831
# current_soc: 56.99835000000831
# Remaining flight time 1st quad: 85.4932503374956
# Remaining flight time: 85.4932503374956
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 72.59325033749559 > 51.0
# Expected gap: 21.59325033749559
# Gap satisfied: true
# Remaining flight time: 85.4932503374956
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 72.59325033749559 > 26.0
# Expected gap: 46.59325033749559
# Gap satisfied: true
# current time: 49.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 51.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 55.99830000000828
# current_soc: 55.99830000000828
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 55.99830000000828
# current_soc: 55.99830000000828
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 55.99830000000828
# current_soc: 55.99830000000828
# Remaining flight time 1st quad: 83.99325033749555
# Remaining flight time: 83.99325033749555
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 71.09325033749555 > 51.0
# Expected gap: 20.093250337495547
# Gap satisfied: true
# Remaining flight time: 83.99325033749555
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 71.09325033749555 > 26.0
# Expected gap: 45.09325033749555
# Gap satisfied: true
# current time: 51.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 52.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 54.99825000000825
# current_soc: 54.99825000000825
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 54.99825000000825
# current_soc: 54.99825000000825
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 54.99825000000825
# current_soc: 54.99825000000825
# Remaining flight time 1st quad: 82.4932503374955
# Remaining flight time: 82.4932503374955
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 69.59325033749549 > 51.0
# Expected gap: 18.59325033749549
# Gap satisfied: true
# Remaining flight time: 82.4932503374955
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 69.59325033749549 > 26.0
# Expected gap: 43.59325033749549
# Gap satisfied: true
# current time: 52.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 54.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 53.99820000000822
# current_soc: 53.99820000000822
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 53.99820000000822
# current_soc: 53.99820000000822
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 53.99820000000822
# current_soc: 53.99820000000822
# Remaining flight time 1st quad: 80.99325033749545
# Remaining flight time: 80.99325033749545
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 68.09325033749545 > 51.0
# Expected gap: 17.093250337495448
# Gap satisfied: true
# Remaining flight time: 80.99325033749545
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 68.09325033749545 > 26.0
# Expected gap: 42.09325033749545
# Gap satisfied: true
# current time: 54.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 55.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 52.99815000000819
# current_soc: 52.99815000000819
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 52.99815000000819
# current_soc: 52.99815000000819
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 52.99815000000819
# current_soc: 52.99815000000819
# Remaining flight time 1st quad: 79.49325033749541
# Remaining flight time: 79.49325033749541
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 66.5932503374954 > 51.0
# Expected gap: 15.593250337495405
# Gap satisfied: true
# Remaining flight time: 79.49325033749541
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 66.5932503374954 > 26.0
# Expected gap: 40.593250337495405
# Gap satisfied: true
# current time: 55.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 57.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 51.99810000000816
# current_soc: 51.99810000000816
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 51.99810000000816
# current_soc: 51.99810000000816
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 51.99810000000816
# current_soc: 51.99810000000816
# Remaining flight time 1st quad: 77.99325033749537
# Remaining flight time: 77.99325033749537
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 65.09325033749536 > 51.0
# Expected gap: 14.093250337495363
# Gap satisfied: true
# Remaining flight time: 77.99325033749537
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 65.09325033749536 > 26.0
# Expected gap: 39.09325033749536
# Gap satisfied: true
# current time: 57.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 58.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 50.99805000000813
# current_soc: 50.99805000000813
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 50.99805000000813
# current_soc: 50.99805000000813
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 50.99805000000813
# current_soc: 50.99805000000813
# Remaining flight time 1st quad: 76.49325033749533
# Remaining flight time: 76.49325033749533
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 63.59325033749532 > 51.0
# Expected gap: 12.59325033749532
# Gap satisfied: true
# Remaining flight time: 76.49325033749533
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 63.59325033749532 > 26.0
# Expected gap: 37.59325033749532
# Gap satisfied: true
# current time: 58.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 60.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 49.9980000000081
# current_soc: 49.9980000000081
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 49.9980000000081
# current_soc: 49.9980000000081
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 49.9980000000081
# current_soc: 49.9980000000081
# Remaining flight time 1st quad: 74.99325033749528
# Remaining flight time: 74.99325033749528
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 62.09325033749528 > 51.0
# Expected gap: 11.093250337495277
# Gap satisfied: true
# Remaining flight time: 74.99325033749528
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 62.09325033749528 > 26.0
# Expected gap: 36.09325033749528
# Gap satisfied: true
# current time: 60.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 61.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 48.99795000000807
# current_soc: 48.99795000000807
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 48.99795000000807
# current_soc: 48.99795000000807
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 48.99795000000807
# current_soc: 48.99795000000807
# Remaining flight time 1st quad: 73.49325033749523
# Remaining flight time: 73.49325033749523
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 60.59325033749522 > 51.0
# Expected gap: 9.59325033749522
# Gap satisfied: true
# Remaining flight time: 73.49325033749523
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 60.59325033749522 > 26.0
# Expected gap: 34.59325033749522
# Gap satisfied: true
# current time: 61.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 63.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 47.99790000000804
# current_soc: 47.99790000000804
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 47.99790000000804
# current_soc: 47.99790000000804
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 47.99790000000804
# current_soc: 47.99790000000804
# Remaining flight time 1st quad: 71.99325033749518
# Remaining flight time: 71.99325033749518
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 59.09325033749518 > 51.0
# Expected gap: 8.093250337495178
# Gap satisfied: true
# Remaining flight time: 71.99325033749518
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 59.09325033749518 > 26.0
# Expected gap: 33.09325033749518
# Gap satisfied: true
# current time: 63.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 64.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 46.997850000008135
# current_soc: 46.997850000008135
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 46.997850000008135
# current_soc: 46.997850000008135
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 46.997850000008135
# current_soc: 46.997850000008135
# Remaining flight time 1st quad: 70.49325033749533
# Remaining flight time: 70.49325033749533
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 57.59325033749532 > 51.0
# Expected gap: 6.59325033749532
# Gap satisfied: true
# Remaining flight time: 70.49325033749533
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 57.59325033749532 > 26.0
# Expected gap: 31.59325033749532
# Gap satisfied: true
# current time: 64.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 66.0
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 45.99780000000849
# current_soc: 45.99780000000849
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 45.99780000000849
# current_soc: 45.99780000000849
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 45.99780000000849
# current_soc: 45.99780000000849
# Remaining flight time 1st quad: 68.99325033749587
# Remaining flight time: 68.99325033749587
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 56.09325033749586 > 51.0
# Expected gap: 5.09325033749586
# Gap satisfied: true
# Remaining flight time: 68.99325033749587
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 56.09325033749586 > 26.0
# Expected gap: 30.09325033749586
# Gap satisfied: true
# current time: 66.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 67.5
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 44.99775000000884
# current_soc: 44.99775000000884
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 44.99775000000884
# current_soc: 44.99775000000884
# integrator.p[i].charge_start_time: 0.0
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 44.99775000000884
# current_soc: 44.99775000000884
# Remaining flight time 1st quad: 67.49325033749639
# Remaining flight time: 67.49325033749639
# TC: 12.900000000000006
# TF - TC > k(T_c + T_delta): 54.593250337496386 > 51.0
# Expected gap: 3.593250337496386
# Gap satisfied: true
# ...
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 64.9454140000038
# current_soc: 64.9454140000038
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 80.9462140000002
# current_soc: 80.9462140000002
# Remaining flight time 1st quad: 71.91325033749986
# Remaining flight time: 121.41325033748343
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 108.51325033748346 > 51.0
# Expected gap: 57.513250337483456
# Gap satisfied: true
# Remaining flight time: 97.41325033748882
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 84.51325033748884 > 26.0
# Expected gap: 58.51325033748884
# Gap satisfied: true
# current time: 277.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 279.0
# integrator.p[i].charge_start_time: 214.42000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 46.94451400001134
# current_soc: 46.94451400001134
# integrator.p[i].charge_start_time: 239.92000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 63.94536400000381
# current_soc: 63.94536400000381
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 79.94616400000021
# current_soc: 79.94616400000021
# Remaining flight time 1st quad: 70.41325033750013
# Remaining flight time: 119.91325033748345
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 107.01325033748347 > 51.0
# Expected gap: 56.01325033748347
# Gap satisfied: true
# Remaining flight time: 95.91325033748885
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 83.01325033748887 > 26.0
# Expected gap: 57.01325033748887
# Gap satisfied: true
# current time: 279.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 280.5
# integrator.p[i].charge_start_time: 214.42000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 45.94446400001152
# current_soc: 45.94446400001152
# integrator.p[i].charge_start_time: 239.92000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 62.945314000004
# current_soc: 62.945314000004
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 78.94611400000022
# current_soc: 78.94611400000022
# Remaining flight time 1st quad: 68.91325033750041
# Remaining flight time: 118.41325033748346
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 105.51325033748348 > 51.0
# Expected gap: 54.513250337483484
# Gap satisfied: true
# Remaining flight time: 94.41325033748913
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 81.51325033748915 > 26.0
# Expected gap: 55.513250337489154
# Gap satisfied: true
# current time: 280.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 282.0
# integrator.p[i].charge_start_time: 214.42000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 44.944414000011705
# current_soc: 44.944414000011705
# integrator.p[i].charge_start_time: 239.92000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 61.94526400000418
# current_soc: 61.94526400000418
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 77.94606400000023
# current_soc: 77.94606400000023
# Remaining flight time 1st quad: 67.41325033750068
# Remaining flight time: 116.91325033748349
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 104.01325033748351 > 51.0
# Expected gap: 53.01325033748351
# Gap satisfied: true
# Remaining flight time: 92.9132503374894
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 80.01325033748942 > 26.0
# Expected gap: 54.013250337489424
# Gap satisfied: true
# current time: 282.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 283.5
# integrator.p[i].charge_start_time: 214.42000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 43.94436400001189
# current_soc: 43.94436400001189
# integrator.p[i].charge_start_time: 239.92000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 60.94521400000436
# current_soc: 60.94521400000436
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 76.94601400000025
# current_soc: 76.94601400000025
# Remaining flight time 1st quad: 65.91325033750095
# Remaining flight time: 115.4132503374835
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 102.51325033748353 > 51.0
# Expected gap: 51.51325033748353
# Gap satisfied: true
# Remaining flight time: 91.41325033748967
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 78.5132503374897 > 26.0
# Expected gap: 52.513250337489694
# Gap satisfied: true
# current time: 283.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 285.0
# integrator.p[i].charge_start_time: 214.42000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 42.94431400001207
# current_soc: 42.94431400001207
# integrator.p[i].charge_start_time: 239.92000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 59.945164000004546
# current_soc: 59.945164000004546
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 75.94596400000026
# current_soc: 75.94596400000026
# Remaining flight time 1st quad: 64.41325033750124
# Remaining flight time: 113.91325033748352
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 101.01325033748354 > 51.0
# Expected gap: 50.01325033748354
# Gap satisfied: true
# Remaining flight time: 89.91325033748996
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 77.01325033748998 > 26.0
# Expected gap: 51.01325033748998
# Gap satisfied: true
# current time: 285.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 286.5
# integrator.p[i].charge_start_time: 214.42000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 41.944264000012254
# current_soc: 41.944264000012254
# integrator.p[i].charge_start_time: 239.92000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 58.94511400000473
# current_soc: 58.94511400000473
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 74.94591400000027
# current_soc: 74.94591400000027
# Remaining flight time 1st quad: 62.91325033750151
# Remaining flight time: 112.41325033748355
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 99.51325033748357 > 51.0
# Expected gap: 48.51325033748357
# Gap satisfied: true
# Remaining flight time: 88.41325033749023
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 75.51325033749025 > 26.0
# Expected gap: 49.51325033749025
# Gap satisfied: true
# current time: 286.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 288.0
# integrator.p[i].charge_start_time: 214.42000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 40.94421400001244
# current_soc: 40.94421400001244
# integrator.p[i].charge_start_time: 239.92000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 57.94506400000491
# current_soc: 57.94506400000491
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 73.94586400000028
# current_soc: 73.94586400000028
# Remaining flight time 1st quad: 61.413250337501786
# Remaining flight time: 110.91325033748356
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 98.01325033748358 > 51.0
# Expected gap: 47.01325033748358
# Gap satisfied: true
# Remaining flight time: 86.9132503374905
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 74.01325033749052 > 26.0
# Expected gap: 48.01325033749052
# Gap satisfied: true
# current time: 288.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 289.5
# integrator.p[i].charge_start_time: 214.42000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 39.94416400001262
# current_soc: 39.94416400001262
# integrator.p[i].charge_start_time: 239.92000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 56.945014000005095
# current_soc: 56.945014000005095
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 72.9458140000003
# current_soc: 72.9458140000003
# Remaining flight time 1st quad: 59.913250337502056
# Remaining flight time: 109.41325033748357
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 96.5132503374836 > 51.0
# Expected gap: 45.5132503374836
# Gap satisfied: true
# Remaining flight time: 85.41325033749078
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 72.5132503374908 > 26.0
# Expected gap: 46.5132503374908
# Gap satisfied: true
# current time: 289.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 291.0
# integrator.p[i].charge_start_time: 214.42000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 38.9441140000128
# current_soc: 38.9441140000128
# integrator.p[i].charge_start_time: 239.92000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 55.94496400000528
# current_soc: 55.94496400000528
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 71.94576400000031
# current_soc: 71.94576400000031
# Remaining flight time 1st quad: 58.41325033750233
# Remaining flight time: 107.9132503374836
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 95.01325033748363 > 51.0
# Expected gap: 44.013250337483626
# Gap satisfied: true
# Remaining flight time: 83.91325033749105
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 71.01325033749107 > 26.0
# Expected gap: 45.01325033749107
# Gap satisfied: true
# current time: 291.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 292.5
# integrator.p[i].charge_start_time: 214.42000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 37.944064000012986
# current_soc: 37.944064000012986
# integrator.p[i].charge_start_time: 239.92000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 54.94491400000546
# current_soc: 54.94491400000546
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 70.94571400000032
# current_soc: 70.94571400000032
# Remaining flight time 1st quad: 56.91325033750261
# Remaining flight time: 106.41325033748362
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 93.51325033748364 > 51.0
# Expected gap: 42.51325033748364
# Gap satisfied: true
# Remaining flight time: 82.41325033749132
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 69.51325033749134 > 26.0
# Expected gap: 43.51325033749134
# Gap satisfied: true
# current time: 292.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 294.0
# integrator.p[i].charge_start_time: 214.42000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 36.94401400001317
# current_soc: 36.94401400001317
# integrator.p[i].charge_start_time: 239.92000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 53.944864000005644
# current_soc: 53.944864000005644
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 69.94566400000033
# current_soc: 69.94566400000033
# Remaining flight time 1st quad: 55.41325033750288
# Remaining flight time: 104.91325033748363
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 92.01325033748365 > 51.0
# Expected gap: 41.013250337483655
# Gap satisfied: true
# Remaining flight time: 80.91325033749159
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 68.01325033749161 > 26.0
# Expected gap: 42.01325033749161
# Gap satisfied: true
# current time: 294.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 295.5
# integrator.p[i].charge_start_time: 214.42000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 35.94396400001335
# current_soc: 35.94396400001335
# integrator.p[i].charge_start_time: 239.92000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 52.94481400000583
# current_soc: 52.94481400000583
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 68.94561400000035
# current_soc: 68.94561400000035
# Remaining flight time 1st quad: 53.91325033750316
# Remaining flight time: 103.41325033748365
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 90.51325033748367 > 51.0
# Expected gap: 39.51325033748367
# Gap satisfied: true
# Remaining flight time: 79.41325033749187
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 66.5132503374919 > 26.0
# Expected gap: 40.5132503374919
# Gap satisfied: true
# current time: 295.5
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 297.0
# integrator.p[i].charge_start_time: 214.42000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 34.943914000013535
# current_soc: 34.943914000013535
# integrator.p[i].charge_start_time: 239.92000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 51.94476400000601
# current_soc: 51.94476400000601
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 67.94556400000036
# current_soc: 67.94556400000036
# Remaining flight time 1st quad: 52.41325033750343
# Remaining flight time: 101.91325033748367
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 89.0132503374837 > 51.0
# Expected gap: 38.0132503374837
# Gap satisfied: true
# Remaining flight time: 77.91325033749214
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 65.01325033749217 > 26.0
# Expected gap: 39.01325033749217
# Gap satisfied: true
# current time: 297.0
# GAP FLAG: false
# =========== Out recompute_committed ==============
# =========== In recompute_committed ==============
# Current time: 298.5
# integrator.p[i].charge_start_time: 214.42000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 33.94386400001372
# current_soc: 33.94386400001372
# integrator.p[i].charge_start_time: 239.92000000000002
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 50.94471400000619
# current_soc: 50.94471400000619
# integrator.p[i].charge_start_time: 263.92
# charge_time_dur: 5.0
# integrator.p[i].landed : 0
# integrator.u[quad_keys[i]].soc : 66.94551400000037
# current_soc: 66.94551400000037
# Remaining flight time 1st quad: 50.913250337503705
# Remaining flight time: 100.41325033748369
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 87.51325033748371 > 51.0
# Expected gap: 36.51325033748371
# Gap satisfied: true
# Remaining flight time: 76.41325033749241
# TC: 12.899999999999977
# TF - TC > k(T_c + T_delta): 63.51325033749244 > 26.0
# Expected gap: 37.51325033749244
# Gap satisfied: true
# current time: 298.5
# GAP FLAG: false
# =========== Out recompute_committed ==============

# %%
params[1].nom_traj.xs;

# %%
sol_nc.u[10].quad3.soc
# Out:
# 89.98175382067019

# %%
include("../src/RefTrajectoryLibrary.jl")
# Out:
# WARNING: replacing module RefTrajLib.
# Main.RefTrajLib

# %%
#Set up visualization
using TrajOptPlots
using MeshCat
using StaticArrays
using RobotZoo:Quadrotor

vis = Visualizer()
render(vis)
# Out:
# ┌ Info: MeshCat server started. You can open the visualizer by visiting the following URL in your browser:
# └ http://127.0.0.1:8700
# MeshCat.DisplayedVisualizer(MeshCat.CoreVisualizer(MeshCat.SceneTrees.SceneNode(nothing, nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), Set{Any}(), ip"127.0.0.1", 8700))

# %%
# [Trajectories] Create and Visualize the reference trajectories
include("../src/RefTrajectoryLibrary.jl")
include("../src/Visualization.jl")
# For Quad 1
t0 = 0.
N = 1200
traj_type = 1
dt = 0.05

# Draw first trajectory
Xref_1, Uref1 = RefTrajLib.get_desired_trajectory(t0, traj_type, N, dt, 1); # The last argument is for the param type
Xref_2, Uref2 = RefTrajLib.get_desired_trajectory(t0, traj_type, N, dt, 2); # The last argument is for the param type
Xref_3, Uref3 = RefTrajLib.get_desired_trajectory(t0, traj_type, N, dt, 3); # The last argument is for the param type
Visualization.vis_traj!(vis, 1, :traj_1, Xref_1[1:1100]; R = 0.01, color = MeshCat.RGBA(1.0, 0.0, 0.0, 2.5))
Visualization.vis_traj!(vis, 1, :traj_2, Xref_2[1:1100]; R = 0.01, color = MeshCat.RGBA(1.0, 1.0, 0.0, 2.5))
Visualization.vis_traj!(vis, 1, :traj_3, Xref_3[1:1100]; R = 0.01, color = MeshCat.RGBA(1.0, 0.0, 1.0, 2.5))
# Out:
# WARNING: replacing module RefTrajLib.
# WARNING: replacing module Visualization.

# %%
# setobject!(vis, HyperRectangle(Vec(0., 0, 0), Vec(1., 1, 1)), MeshCat.MeshPhongMaterial(color = MeshCat.RGBA(0.0,1.0,0.0,0.2)))
# settransform!(vis, MeshCat.Translation(-0.5, -0.5, 0))
# # setprop!(vis, "material.opacity", 0.5)  # Correct usage of setprop!

# %% [markdown]
# ### Draw Bounds

# %%
X_bound = [[-3.60, -4.80, 1.0],
            [0.0, -4.80, 1.0],
            [2.40, -4.80, 1.0],
            [2.40, 0.0, 1.0],
            [2.40, 1.80, 1.0],
            [0.0, 1.80, 1.0],
            [-3.60, 1.80, 1.0],
            [-3.40, -1.40, 1.0]]

# Generate 100 values for z from 0 to 2.0
z_values = range(0, stop=8.0, length=400)

# Generate the 500-element vector (each with 100 points)
points = [[x, y, z] for (x, y, _) in X_bound for z in z_values];

Visualization.vis_traj!(vis, 2, :lab_bound, points; R = 0.01, color = MeshCat.RGBA(0.0, 1.0, 0.0, 2.5))

# %%
# [Quadrotors] Visualize the Quadrotors
Visualization.N_animate_system_geometric!(vis, X1, 3, 0.01)

# %% [markdown]
# # PLots

# %%
charge_dist_1 = params[1].charge_dist
charge_dist_2 = params[2].charge_dist
charge_dist_3 = params[3].charge_dist;

# %%
# Extract charge distributions
charge_dists = [params[i].charge_dist for i in 1:3]

# Total duration
total_time = 150

# Create a plot
plot()

# Plot each charge distribution with time on the x-axis
for i in 1:3
    num_points = length(charge_dists[i])
    time = range(0, total_time, length=num_points)  # Create time vector
    plot!(time, charge_dists[i], linewidth=3, label="")
end

# Show the plot
xlabel!("Time (s)")
ylabel!("Distance to charging station (m)")
title!("Charge Distribution Over Time")
display(plot!())

# %%
savefig("charge_dist.svg")
# Out:
# "/home/kbn/Kaleb_Data/PhD_Research/mEclares/exp_code/charge_dist.svg"

# %%
savefig("charge_dist.png")
# Out:
# "/home/kbn/Kaleb_Data/PhD_Research/mEclares/exp_code/charge_dist.png"

# %%
soc_values_1 = [sol_nc.u[i].quad1.soc for i in eachindex(sol_nc.u)]
soc_values_2 = [sol_nc.u[i].quad2.soc for i in eachindex(sol_nc.u)]
soc_values_3 = [sol_nc.u[i].quad3.soc for i in eachindex(sol_nc.u)];

# %%
# Create time vector
num_points = length(soc_values_1)  # Assuming all soc_values have the same length
time = range(0, total_time, length=num_points)

# Create a plot
plot()

# Plot SOC values with customized appearance
plot!(time, soc_values_1, linewidth=3, label="")
plot!(time, soc_values_2, linewidth=3, label="")
plot!(time, soc_values_3, linewidth=3, label="")

# Set axis labels, title, and y-axis limits
xlabel!("Time (s)")
ylabel!("State of Charge (SoC)")
# title!("SOC Evolution Over Time")
ylims!(-2, 52)  # Set y-axis limits from 0 to 50

# %%
# Total duration
total_time = 150

# Create time vector
num_points = length(soc_values_1)  # Assuming all soc_values have the same length
time = range(0, total_time, length=num_points)

# Convert SoC values to percentage
soc_percentage_1 = soc_values_1 .* 2
soc_percentage_2 = soc_values_2 .* 2
soc_percentage_3 = soc_values_3 .* 2

# Create a plot
plot()

# Plot SOC percentages with customized appearance
plot!(time, soc_percentage_1, linewidth=3, label="")
plot!(time, soc_percentage_2, linewidth=3, label="")
plot!(time, soc_percentage_3, linewidth=3, label="")

# Set axis labels, title, and y-axis limits
xlabel!("Time (s)")
ylabel!("State of Charge (SoC) [%]")  # SoC in percentage
ylims!(-4, 104)  # Set y-axis limits from 0 to 100%

# %%
# Save as SVG
savefig("soc_percentage_evolution.svg")
# Out:
# "/home/kbn/Kaleb_Data/PhD_Research/mEclares/exp_code/soc_percentage_evolution.svg"

# %%
# Save as PNG
savefig("soc_percentage_evolution.png")
# Out:
# "/home/kbn/Kaleb_Data/PhD_Research/mEclares/exp_code/soc_percentage_evolution.png"
